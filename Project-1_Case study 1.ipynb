# %% [markdown]
# # Project-1_case 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df.head()
# Out:
#                            Indicator PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# ...

# %%
df1 =pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
df1 .head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %%
df1.head()
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
# 2  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999    28
# 3  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999    39
# 4  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999     0
#
#    TMIN  WDFG  PGTM  ...   WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 2    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 3    11 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 4   -22 -9999 -9999  ...  -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
# 2 -9999 -9999
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                                             Indicator PUBLISH STATES  Year  \
# 0                    Life expectancy at birth (years)      Published  1990
# 1                    Life expectancy at birth (years)      Published  2000
# 2                   Life expectancy at age 60 (years)      Published  2012
# 3                   Life expectancy at age 60 (years)      Published  2000
# 4                    Life expectancy at birth (years)      Published  2012
# 5                    Life expectancy at birth (years)      Published  2000
# 6                   Life expectancy at age 60 (years)      Published  1990
# 7                   Life expectancy at age 60 (years)      Published  2012
# 8                    Life expectancy at birth (years)      Published  2012
# 9                    Life expectancy at birth (years)      Published  2000
# 10                   Life expectancy at birth (years)      Published  2012
# ...

# %%
df1.info
# Out:
# <bound method DataFrame.info of                   STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  \
# 0       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999
# 1       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999
# 2       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310103 -9999 -9999 -9999
# 3       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310105    13 -9999 -9999
# 4       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310106 -9999 -9999 -9999
# 5       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310107    10 -9999 -9999
# 6       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310108    13 -9999 -9999
# 7       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310109    10 -9999 -9999
# 8       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310110 -9999 -9999 -9999
# 9       GHCND:GME00111445  BERLIN TEMPELHOF GM  19310112 -9999 -9999 -9999
# 10      GHCND:GME00111445  BERLIN TEMPELHOF GM  19310113    13 -9999 -9999
# ...

# %% [markdown]
# Get the row and column name from the data. Change the name from any of the above file and store the changes made permanently. Change the names of multiple columns.

# %%
np.array(df.index)
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
np.array(df1.index)
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %%
df.columns
# Out:
# Index(['Indicator', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
df.rename(columns={"Indicator":"Indicator Id"},inplace=True)

# %%
df.columns
# Out:
# Index(['Indicator Id', 'PUBLISH STATES', 'Year', 'WHO region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %%
df.rename(columns={"PUBLISH STATES":"Publication states","WHO region":"WHO Region"},inplace=True)

# %%
df.columns
# Out:
# Index(['Indicator Id', 'Publication states', 'Year', 'WHO Region',
#        'World Bank income group', 'Country', 'Sex', 'Display Value', 'Numeric',
#        'Low', 'High', 'Comments'],
#       dtype='object')

# %% [markdown]
# # In following commond, Year column has been arraned in ascending order.

# %%
df.sort_values(["Year"], ascending=True)
# Out:
#                                          Indicator Id Publication states  \
# 0                    Life expectancy at birth (years)          Published
# 1270                 Life expectancy at birth (years)          Published
# 3193                 Life expectancy at birth (years)          Published
# 3194                 Life expectancy at birth (years)          Published
# 3197                Life expectancy at age 60 (years)          Published
# 1264                 Life expectancy at birth (years)          Published
# 3199                Life expectancy at age 60 (years)          Published
# 1262                Life expectancy at age 60 (years)          Published
# 1259                 Life expectancy at birth (years)          Published
# 3203                Life expectancy at age 60 (years)          Published
# 1273                Life expectancy at age 60 (years)          Published
# 3204                 Life expectancy at birth (years)          Published
# ...

# %% [markdown]
# # To make multiple column in ascending order, lets convert the sequence of columns in expected form

# %%
df.sort_values(["Year","Country", "WHO Region","Publication states","Display Value","Numeric"], ascending=True)
# Out:
#           Country                                     Indicator Id  \
# 2959  Afghanistan                Life expectancy at age 60 (years)
# 1395  Afghanistan                Life expectancy at age 60 (years)
# 555   Afghanistan                Life expectancy at age 60 (years)
# 554   Afghanistan                 Life expectancy at birth (years)
# 965   Afghanistan                 Life expectancy at birth (years)
# 1792  Afghanistan                 Life expectancy at birth (years)
# 3114      Albania                Life expectancy at age 60 (years)
# 1522      Albania                Life expectancy at age 60 (years)
# 1931      Albania                Life expectancy at age 60 (years)
# 299       Albania                 Life expectancy at birth (years)
# 689       Albania                 Life expectancy at birth (years)
# 3113      Albania                 Life expectancy at birth (years)
# 3257      Algeria                Life expectancy at age 60 (years)
# ...

# %%
df[["Indicator Id", "Country", "Year", "WHO Region", "Publication states"]].head()
# Out:
#                         Indicator Id               Country  Year  \
# 0   Life expectancy at birth (years)               Andorra  1990
# 1   Life expectancy at birth (years)               Andorra  2000
# 2  Life expectancy at age 60 (years)               Andorra  2012
# 3  Life expectancy at age 60 (years)               Andorra  2000
# 4   Life expectancy at birth (years)  United Arab Emirates  2012
#
#               WHO Region Publication states
# 0                 Europe          Published
# 1                 Europe          Published
# 2                 Europe          Published
# 3                 Europe          Published
# 4  Eastern Mediterranean          Published

# %% [markdown]
# # OR

# %%
ColTitles=["Indicator Id", "Country", "Year", "WHO Region", "Publication states"]
df.reindex(columns=ColTitles)
# Out:
#                                          Indicator Id  \
# 0                    Life expectancy at birth (years)
# 1                    Life expectancy at birth (years)
# 2                   Life expectancy at age 60 (years)
# 3                   Life expectancy at age 60 (years)
# 4                    Life expectancy at birth (years)
# 5                    Life expectancy at birth (years)
# 6                   Life expectancy at age 60 (years)
# 7                   Life expectancy at age 60 (years)
# 8                    Life expectancy at birth (years)
# 9                    Life expectancy at birth (years)
# 10                   Life expectancy at birth (years)
# 11                   Life expectancy at birth (years)
# 12                  Life expectancy at age 60 (years)
# 13                   Life expectancy at birth (years)
# 14                   Life expectancy at birth (years)
# 15                   Life expectancy at birth (years)
# ...

# %%
cols = df.columns.tolist()

# %%
cols=ColTitles]
# Out:
# ['Country',
#  'Indicator Id',
#  'Publication states',
#  'Year',
#  'WHO Region',
#  'World Bank income group',
#  'Sex',
#  'Display Value',
#  'Numeric',
#  'Low',
#  'High',
#  'Comments']

# %% [markdown]
# Modified sequence of columns, Make "Country as the first column"

# %%
df = df[['Country','Indicator Id',
 'Publication states',
 'Year',
 'WHO Region',
 'World Bank income group', 
 'Sex',
 'Display Value',
 'Numeric',
 'Low',
 'High',
 'Comments']]
df.head()
# Out:
#                 Country                       Indicator Id Publication states  \
# 0               Andorra   Life expectancy at birth (years)          Published
# 1               Andorra   Life expectancy at birth (years)          Published
# 2               Andorra  Life expectancy at age 60 (years)          Published
# 3               Andorra  Life expectancy at age 60 (years)          Published
# 4  United Arab Emirates   Life expectancy at birth (years)          Published
#
#    Year             WHO Region World Bank income group         Sex  \
# 0  1990                 Europe             High-income  Both sexes
# 1  2000                 Europe             High-income  Both sexes
# 2  2012                 Europe             High-income      Female
# 3  2000                 Europe             High-income  Both sexes
# 4  2012  Eastern Mediterranean             High-income      Female
#
#    Display Value  Numeric  Low  High  Comments
# ...

# %%
df
# Out:
#                                  Country  \
# 0                                Andorra
# 1                                Andorra
# 2                                Andorra
# 3                                Andorra
# 4                   United Arab Emirates
# 5                    Antigua and Barbuda
# 6                    Antigua and Barbuda
# 7                    Antigua and Barbuda
# 8                              Australia
# 9                              Australia
# 10                             Australia
# 11                               Austria
# 12                               Austria
# 13                               Belgium
# 14                               Bahrain
# 15                               Bahrain
# 16                               Bahrain
# 17                               Bahamas
# 18                               Bahamas
# 19                              Barbados
# 20                              Barbados
# 21                              Barbados
# ...

# %% [markdown]
# # Subset row 11, 24, 37

# %%
df_newlist=df.iloc[[11, 24, 37]]

# %%
df_newlist
# Out:
#               Country                       Indicator Id Publication states  \
# 11            Austria   Life expectancy at birth (years)          Published
# 24  Brunei Darussalam  Life expectancy at age 60 (years)          Published
# 37             Cyprus  Life expectancy at age 60 (years)          Published
#
#     Year       WHO Region World Bank income group     Sex  Display Value  \
# 11  2012           Europe             High-income  Female             83
# 24  2012  Western Pacific             High-income  Female             21
# 37  2012           Europe             High-income  Female             26
#
#     Numeric  Low  High  Comments
# 11     83.0  NaN   NaN       NaN
# 24     21.0  NaN   NaN       NaN
# 37     26.0  NaN   NaN       NaN

# %% [markdown]
# # Subset rows excluding 5,12,23 and 56.

# %%
df_newlist1=df.drop([5, 12, 23, 56])

# %%
df_newlist1
# Out:
#                                  Country  \
# 0                                Andorra
# 1                                Andorra
# 2                                Andorra
# 3                                Andorra
# 4                   United Arab Emirates
# 6                    Antigua and Barbuda
# 7                    Antigua and Barbuda
# 8                              Australia
# 9                              Australia
# 10                             Australia
# 11                               Austria
# 13                               Belgium
# 14                               Bahrain
# 15                               Bahrain
# 16                               Bahrain
# 17                               Bahamas
# 18                               Bahamas
# 19                              Barbados
# 20                              Barbados
# 21                              Barbados
# 22                     Brunei Darussalam
# 24                     Brunei Darussalam
# ...

# %% [markdown]
# Finished
