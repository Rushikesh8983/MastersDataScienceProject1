# %% [markdown]
# # Project 1_case 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
users =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
sessions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
transactions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

# %%
users.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
sessions.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
transactions.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %%
products.head()
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %% [markdown]
# # Join users to transaction keeping all rows from transactions and only matching rows from users
# dfnew=pd.merge(transactions,users, how='left')
# or
# dfnew=pd.merge(transactions,users, how='outer')#not preferred in this case

# %%
dfnew=pd.merge(transactions,users, how='left')

# %%
dfnew
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21      7          2         1       NaN
# 1              2      2011-05-26      3          4         1  Caroline
# 2              3      2011-06-16      3          3         1  Caroline
# 3              4      2012-08-26      1          2         3   Charles
# 4              5      2013-06-06      2          4         1     Pedro
# 5              6      2013-12-23      2          5         6     Pedro
# 6              7      2013-12-30      3          4         1  Caroline
# 7              8      2014-04-24    NaN          2         3       NaN
# 8              9      2015-04-24      7          4         3       NaN
# 9             10      2016-05-08      3          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %% [markdown]
# # Which transactions have a UserID not in users

# %%
dfnew.isnull().any()
# Out:
# TransactionID      False
# TransactionDate    False
# UserID              True
# ProductID          False
# Quantity           False
# User                True
# Gender              True
# Registered          True
# Cancelled           True
# dtype: bool

# %%
dfnew[dfnew['User'].isnull()].head()
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity User Gender  \
# 0              1      2010-08-21      7          2         1  NaN    NaN
# 7              8      2014-04-24    NaN          2         3  NaN    NaN
# 8              9      2015-04-24      7          4         3  NaN    NaN
#
#   Registered Cancelled
# 0        NaN       NaN
# 7        NaN       NaN
# 8        NaN       NaN

# %% [markdown]
# # Join users to transactions, keeping only rows from transactions and users that match via userID
# dfnew1=pd.merge(transactions,users, how='inner')

# %%
dfnew1=pd.merge(transactions,users, how='inner')
dfnew1.head()
# Out:
#    TransactionID TransactionDate UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26      3          4         1  Caroline
# 1              3      2011-06-16      3          3         1  Caroline
# 2              7      2013-12-30      3          4         1  Caroline
# 3             10      2016-05-08      3          4         4  Caroline
# 4              4      2012-08-26      1          2         3   Charles
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN

# %% [markdown]
# # Join users to transactions, displaying all matching rows and all non matching rows

# %%
dfnew2=pd.merge(transactions,users, how='outer')
dfnew2.head()
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0            1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1            9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2            2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3            3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4            7.0      2013-12-30     3.0        4.0       1.0  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1     NaN         NaN         NaN
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4  female  2012-10-23  2016-06-07

# %%
dfnew3=pd.merge(users,sessions, how='outer')
dfnew3.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled  SessionID SessionDate
# 0       1   Charles    male  2012-12-21         NaN        NaN         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08        1.0  2010-01-05
# 2       2     Pedro    male  2010-08-01  2010-08-08        2.0  2010-08-01
# 3       2     Pedro    male  2010-08-01  2010-08-08        3.0  2010-11-25
# 4       3  Caroline  female  2012-10-23  2016-06-07        7.0  2012-12-21

# %%
dfnew3.info
# Out:
# <bound method DataFrame.info of     UserID      User  Gender  Registered   Cancelled  SessionID SessionDate
# 0        1   Charles    male  2012-12-21         NaN        NaN         NaN
# 1        2     Pedro    male  2010-08-01  2010-08-08        1.0  2010-01-05
# 2        2     Pedro    male  2010-08-01  2010-08-08        2.0  2010-08-01
# 3        2     Pedro    male  2010-08-01  2010-08-08        3.0  2010-11-25
# 4        3  Caroline  female  2012-10-23  2016-06-07        7.0  2012-12-21
# 5        4   Brielle  female  2013-07-17         NaN        5.0  2011-10-19
# 6        4   Brielle  female  2013-07-17         NaN        6.0  2012-10-23
# 7        4   Brielle  female  2013-07-17         NaN        8.0  2013-05-22
# 8        4   Brielle  female  2013-07-17         NaN        9.0  2013-07-17
# 9        4   Brielle  female  2013-07-17         NaN       10.0  2016-01-11
# 10       5  Benjamin    male  2010-11-25         NaN        4.0  2011-09-21>

# %% [markdown]
# # Session occured on same date i.e. registration date equal to sessiondate

# %%
dfnew3_samedate = dfnew3.query("Registered == SessionDate")
dfnew3_samedate
# Out:
#    UserID     User  Gender  Registered   Cancelled  SessionID SessionDate
# 2       2    Pedro    male  2010-08-01  2010-08-08        2.0  2010-08-01
# 8       4  Brielle  female  2013-07-17         NaN        9.0  2013-07-17

# %% [markdown]
# # 17. Build a dataset with every possible (UserID, ProductID) pair (cross join)

# %%
df1 = pd.DataFrame({'key': np.repeat(1, users.shape[0]), 'UserID': users.UserID})
df2 = pd.DataFrame({'key': np.repeat(1, products.shape[0]), 'ProductID': products.ProductID})
pd.merge(df1, df2,on='key')[['UserID', 'ProductID']]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %% [markdown]
# # 18. Determine how much quantity of each product was purchased by each user

# %%
df1 = pd.DataFrame({'key': np.repeat(1, users.shape[0]), 'UserID': users.UserID})
df2 = pd.DataFrame({'key': np.repeat(1, products.shape[0]), 'ProductID': products.ProductID})
user_products = pd.merge(df1, df2,on='key')[['UserID', 'ProductID']]
pd.merge(user_products, transactions, how='left', on=['UserID', 'ProductID']).groupby(['UserID', 'ProductID']).apply(lambda x: pd.Series(dict(
    Quantity=x.Quantity.sum()
))).reset_index().fillna(0)
# Out:
#     UserID  ProductID  Quantity
# 0        1          1       0.0
# 1        1          2       3.0
# 2        1          3       0.0
# 3        1          4       0.0
# 4        1          5       0.0
# 5        2          1       0.0
# 6        2          2       0.0
# 7        2          3       0.0
# 8        2          4       1.0
# 9        2          5       6.0
# 10       3          1       0.0
# 11       3          2       0.0
# 12       3          3       1.0
# 13       3          4       6.0
# 14       3          5       0.0
# 15       4          1       0.0
# 16       4          2       0.0
# 17       4          3       0.0
# 18       4          4       0.0
# 19       4          5       0.0
# 20       5          1       0.0
# 21       5          2       0.0
# 22       5          3       0.0
# 23       5          4       0.0
# 24       5          5       0.0

# %% [markdown]
# # 19. For each user, get each possible pair of pair transactions (TransactionID1, TransacationID2)

# %%
pd.merge(transactions, transactions, on='UserID')
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# ...

# %%
pd.merge(users, transactions.groupby('UserID').first().reset_index(), how='left', on='UserID')
# Out:
#   UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0      1   Charles    male  2012-12-21         NaN            4.0
# 1      2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2      3  Caroline  female  2012-10-23  2016-06-07            2.0
# 3      4   Brielle  female  2013-07-17         NaN            NaN
# 4      5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaN        NaN       NaN
# 4             NaN        NaN       NaN

# %% [markdown]
# # 20. Join each user to his/her first occuring transaction in the transaction table

# %%
pd.merge(users,transactions, on='UserID', how='outer', validate="one_to_many")
# Out:
#     UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0      1.0   Charles    male  2012-12-21         NaN            4.0
# 1      2.0     Pedro    male  2010-08-01  2010-08-08            5.0
# 2      2.0     Pedro    male  2010-08-01  2010-08-08            6.0
# 3      3.0  Caroline  female  2012-10-23  2016-06-07            2.0
# 4      3.0  Caroline  female  2012-10-23  2016-06-07            3.0
# 5      3.0  Caroline  female  2012-10-23  2016-06-07            7.0
# 6      3.0  Caroline  female  2012-10-23  2016-06-07           10.0
# 7      4.0   Brielle  female  2013-07-17         NaN            NaN
# 8      5.0  Benjamin    male  2010-11-25         NaN            NaN
# 9      7.0       NaN     NaN         NaN         NaN            1.0
# 10     7.0       NaN     NaN         NaN         NaN            9.0
# 11     NaN       NaN     NaN         NaN         NaN            8.0
#
#    TransactionDate  ProductID  Quantity
# 0       2012-08-26        2.0       3.0
# ...
